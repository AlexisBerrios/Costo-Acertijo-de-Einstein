# %%
class Casa:
    color=""
    nacionalidad=""
    def __init__(self,c,n):
        self.color=c
        self.nac=n

colores=["blanco","verde","azul"]
nacion=["Sueco","Danes","Aleman"]

'''
TODAS LAS POSIBLES COMBINACIONES (se repiten en cada casa)
for contCasa in range(2):
    for c in colores: #combinaciones color nacion
        for n in nacion:
            print("Casa n",contCasa+1," ",c,n)
'''
'''
#apoyarnos de conjuntos, para que no pueda haber elementos repetidos
#EJEMPLOS DE CONJUNTOS
a=[1,2,3,4,5]
b=[1,2,3,4,5] #listas
a=set(a)
b=set(b) #los conviertes a conjuntos
print(a,b)
a=b      #aqui solo se va a imprimir una serie, ya que no puede haber elementos
print(a) #repetidos
'''
#Einstein
colores=set(["Azul","Verde","blanco","Rojo"])
nacion=set(["Sueco","Danes","Aleman","Britanico"])
mascota=set(["perro","gato","tortuga","Pez"])#meter el valor directamente en los conjuntos
bebida=set([])
cigarrillos=set([])

for cc1 in colores:
    for cc2 in nacion-set([cc1]):
        for cc3 in mascota-set([cc2]):
            if(cc2!=cc3):   #depurar repetidos como principiante xd
                print(cc1,cc2,cc3)
# Out:
# blanco Sueco gato
# blanco Sueco tortuga
# blanco Sueco Pez
# blanco Sueco perro
# blanco Danes gato
# blanco Danes tortuga
# blanco Danes Pez
# blanco Danes perro
# blanco Aleman gato
# blanco Aleman tortuga
# blanco Aleman Pez
# blanco Aleman perro
# blanco Britanico gato
# blanco Britanico tortuga
# blanco Britanico Pez
# blanco Britanico perro
# Verde Sueco gato
# Verde Sueco tortuga
# Verde Sueco Pez
# Verde Sueco perro
# Verde Danes gato
# Verde Danes tortuga
# Verde Danes Pez
# Verde Danes perro
# Verde Aleman gato
# Verde Aleman tortuga
# Verde Aleman Pez
# Verde Aleman perro
# Verde Britanico gato
# Verde Britanico tortuga
# Verde Britanico Pez
# Verde Britanico perro
# Azul Sueco gato
# Azul Sueco tortuga
# Azul Sueco Pez
# Azul Sueco perro
# Azul Danes gato
# Azul Danes tortuga
# Azul Danes Pez
# Azul Danes perro
# Azul Aleman gato
# Azul Aleman tortuga
# Azul Aleman Pez
# Azul Aleman perro
# Azul Britanico gato
# Azul Britanico tortuga
# Azul Britanico Pez
# ...

# %%
class Casa:
    color=""
    nacionalidad=""
    def __init__(self,c,n):
        self.color=c
        self.nac=n

colores=["blanco","verde","azul"]
nacion=["Sueco","Danes","Aleman"]

'''
TODAS LAS POSIBLES COMBINACIONES (se repiten en cada casa)
for contCasa in range(2):
    for c in colores: #combinaciones color nacion
        for n in nacion:
            print("Casa n",contCasa+1," ",c,n)
'''
'''
#apoyarnos de conjuntos, para que no pueda haber elementos repetidos
#EJEMPLOS DE CONJUNTOS
a=[1,2,3,4,5]
b=[1,2,3,4,5] #listas
a=set(a)
b=set(b) #los conviertes a conjuntos
print(a,b)
a=b      #aqui solo se va a imprimir una serie, ya que no puede haber elementos
print(a) #repetidos
'''
#Einstein
colores=set(["Azul","Verde"])
nacion=set(["Sueco","Danes"])
mascota=set(["perro","gato"])#meter el valor directamente en los conjuntos
bebida=set(["ron","whisky"])
cigarrillos=set(["marca2","marca1"])

'''
colores=set(["Azul","Verde","Rojo","Amarillo"])
nacion=set(["Sueco","Danes","Aleman","Britanico"])
mascota=set(["perro","gato","tortuga","Hamster"])#meter el valor directamente en los conjuntos
bebida=set(["ron","whisky","agua","refresco"])
cigarrillos=set(["",""])
'''

cont=0
for cc1 in colores:
    for cc2 in nacion-set([cc1]):
        for cc3 in mascota-set([cc2]): 
            for cc4 in bebida-set([cc3]):
                for cc5 in cigarrillos-set([cc4]):
                  if(cc4!=cc5):   #depurar repetidos como principiante xd
                    cont=cont+1
                    print(cont,cc1,cc2,cc3,cc4,cc5)
# Out:
# 1 Verde Danes gato ron marca1
# 2 Verde Danes gato ron marca2
# 3 Verde Danes gato whisky marca1
# 4 Verde Danes gato whisky marca2
# 5 Verde Danes perro ron marca1
# 6 Verde Danes perro ron marca2
# 7 Verde Danes perro whisky marca1
# 8 Verde Danes perro whisky marca2
# 9 Verde Sueco gato ron marca1
# 10 Verde Sueco gato ron marca2
# 11 Verde Sueco gato whisky marca1
# 12 Verde Sueco gato whisky marca2
# 13 Verde Sueco perro ron marca1
# 14 Verde Sueco perro ron marca2
# 15 Verde Sueco perro whisky marca1
# 16 Verde Sueco perro whisky marca2
# 17 Azul Danes gato ron marca1
# 18 Azul Danes gato ron marca2
# 19 Azul Danes gato whisky marca1
# 20 Azul Danes gato whisky marca2
# 21 Azul Danes perro ron marca1
# 22 Azul Danes perro ron marca2
# 23 Azul Danes perro whisky marca1
# 24 Azul Danes perro whisky marca2
# 25 Azul Sueco gato ron marca1
# 26 Azul Sueco gato ron marca2
# 27 Azul Sueco gato whisky marca1
# 28 Azul Sueco gato whisky marca2
# 29 Azul Sueco perro ron marca1
# ...
